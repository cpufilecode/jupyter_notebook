# %%
# 9) input() 함수로 정보 압룍벋가

txt1 = input()
# Out:
# test

# %%
# 10) input() 함수에서 안내 멘트 보이기
txt2 = input("점심을 무엇을 드셨나요?")
# Out:
# 점심을 무엇을 드셨나요?밥

# %%
# 11) 출력 되는 양식을 지정하여 정보를 입력받기

area_no = input('''
1. 서울 2. 대전 3. 광주 4. 부산
5. 경남 6. 경북 7. 충청 8. 제주
''')
